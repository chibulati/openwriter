# %% [markdown]
# <a href="https://colab.research.google.com/github/chibulati/openwriter/blob/master/Qwen3_TTS_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 🏷️ **Credits & License**
#
# * 🔗 [Qwen3-TTS GitHub Repository](https://github.com/QwenLM/Qwen3-TTS)
# * 🤗 [Qwen3-TTS on Hugging Face](https://huggingface.co/collections/Qwen/qwen3-tts)
# * 📄 **License**: Provided under the [Apache License 2.0](https://github.com/QwenLM/Qwen3-TTS?tab=Apache-2.0-1-ov-file)
# * 🤗 [Try Qwen3-TTS on HuggingFace Space](https://huggingface.co/spaces/Qwen/Qwen3-TTS)
#
#
#
# ### ⚠️ **Usage Disclaimer**
#
# Use of this voice cloning model is subject to strict ethical and legal standards. By using this tool, you agree **not to** engage in any of the following prohibited activities:
#
# * **Fraud or Deception**: Using cloned voices to create misleading or fraudulent content.
# * **Impersonation**: Replicating someone’s voice without their explicit permission, especially for malicious, harmful, or deceptive purposes.
# * **Illegal Activities**: Employing the model in any manner that violates local, national, or international laws and regulations.
# * **Harmful Content Generation**: Creating offensive, defamatory, or unethical material, including content that spreads misinformation or causes harm.
#
# > ⚖️ **Legal Responsibility**
# > The developers of this tool disclaim all liability for misuse. **Users bear full responsibility** for ensuring that their usage complies with all applicable laws, regulations, and ethical guidelines.

# %%
#@title Install Qwen3-TTS
# %cd /content/
# !rm -rf /content/Qwen3-TTS-Colab
# !git clone https://github.com/NeuralFalconYT/Qwen3-TTS-Colab.git
# !git clone https://github.com/QwenLM/Qwen3-TTS.git
# %cd Qwen3-TTS
# !pip install -e .
# !pip install faster-whisper==1.1.1
# !pip install ctranslate2==4.5.0
# !pip install pysrt
# !pip install sentencex
from IPython.display import Audio,display
from IPython.display import clear_output
import time
clear_output()

display(Audio("https://raw.githubusercontent.com/NeuralFalconYT/Useful-Function/refs/heads/main/audio/warning.mp3", autoplay=True))
time.sleep(6)
clear_output()
# time.sleep(5)
# import os
# os.kill(os.getpid(), 9)

# %%
# %cd /content/Qwen3-TTS-Colab
# !python app.py --share --debug
# Out:
# /content/Qwen3-TTS-Colab
# 2026-05-24 04:39:50.133633: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# ********
# Warning: flash-attn is not installed. Will only run the manual PyTorch version. Please install flash-attn for faster inference.
# ********
#
# /bin/sh: 1: sox: not found
# WARNING:sox:SoX could not be found!
#
#     If you do not have SoX, proceed here:
#      - - - http://sox.sourceforge.net/ - - -
#
#     If you do (or think that you should) have SoX, double-check your
#     path variables.
#
# /content/Qwen3-TTS-Colab/app.py:354: DeprecationWarning: The 'theme' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'theme' to Blocks.launch() instead.
#   with gr.Blocks(theme=theme, css=css, title="Qwen3-TTS Demo") as demo:
# /content/Qwen3-TTS-Colab/app.py:354: DeprecationWarning: The 'css' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'css' to Blocks.launch() instead.
#   with gr.Blocks(theme=theme, css=css, title="Qwen3-TTS Demo") as demo:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://b30670ba50ffb173e3.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# Starting transcription for: /tmp/gradio/c03d12c356b568e15c6bf45ea616b7fe3c1466a2fd2314a986230a27d88fc3b2/main voice clone.mp3
#
# config.json: 0.00B [00:00, ?B/s]
#
# preprocessor_config.json: 100% 340/340 [00:00<00:00, 2.36MB/s]
# config.json: 2.26kB [00:00, 849kB/s]
#
#
#
# vocabulary.json: 1.07MB [00:00, 21.7MB/s]
# tokenizer.json: 2.71MB [00:00, 50.6MB/s]
# model.bin: 100% 1.62G/1.62G [00:10<00:00, 149MB/s]
# Starting transcription for: /tmp/gradio/c03d12c356b568e15c6bf45ea616b7fe3c1466a2fd2314a986230a27d88fc3b2/main voice clone.mp3
# ⚠️ The text is too long. Breaking it into smaller pieces for TTS.
# Fetching 13 files:   0% 0/13 [00:00<?, ?it/s]
# generation_config.json: 100% 245/245 [00:00<00:00, 1.30MB/s]
#
# preprocessor_config.json: 100% 127/127 [00:00<00:00, 863kB/s]
#
# README.md: 57.8kB [00:00, 92.6MB/s]
#
# .gitattributes: 1.52kB [00:00, 10.1MB/s]
# Fetching 13 files:   8% 1/13 [00:00<00:01,  7.63it/s]
# merges.txt: 0.00B [00:00, ?B/s]
#
# config.json: 4.49kB [00:00, 17.9MB/s]
#
#
# config.json: 2.34kB [00:00, 11.7MB/s]
# merges.txt: 1.67MB [00:00, 39.7MB/s]
#
# configuration.json: 100% 76.0/76.0 [00:00<00:00, 723kB/s]
#
# preprocessor_config.json: 100% 234/234 [00:00<00:00, 1.91MB/s]
#
# tokenizer_config.json: 7.34kB [00:00, 44.4MB/s]
#
# model.safetensors:   0% 0.00/3.86G [00:00<?, ?B/s]
#
# vocab.json: 0.00B [00:00, ?B/s]
#
#
# vocab.json: 2.78MB [00:00, 58.9MB/s]
#
# model.safetensors:   0% 0.00/3.86G [00:00<?, ?B/s]
#
#
# speech_tokenizer/model.safetensors:   0% 0.00/682M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/3.86G [00:00<?, ?B/s]
#
#
# speech_tokenizer/model.safetensors:   0% 0.00/682M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/3.86G [00:00<?, ?B/s]
#
#
# speech_tokenizer/model.safetensors:   0% 0.00/682M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/3.86G [00:00<?, ?B/s]
#
#
# speech_tokenizer/model.safetensors:   0% 0.00/682M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/3.86G [00:01<?, ?B/s]
#
#
# speech_tokenizer/model.safetensors:   0% 0.00/682M [00:01<?, ?B/s]
# model.safetensors:   2% 67.1M/3.86G [00:01<00:11, 344MB/s]
#
#
# speech_tokenizer/model.safetensors:   0% 0.00/682M [00:01<?, ?B/s]
#
#
# speech_tokenizer/model.safetensors:  10% 67.1M/682M [00:01<00:01, 359MB/s]
# model.safetensors:   5% 201M/3.86G [00:02<00:30, 119MB/s]
#
#
# speech_tokenizer/model.safetensors:  20% 134M/682M [00:03<00:08, 64.3MB/s]
#
#
# speech_tokenizer/model.safetensors:  29% 201M/682M [00:03<00:04, 99.2MB/s]
# model.safetensors:   7% 268M/3.86G [00:04<00:45, 78.6MB/s]
#
#
# speech_tokenizer/model.safetensors:  39% 268M/682M [00:04<00:05, 74.4MB/s]
#
#
# speech_tokenizer/model.safetensors:  59% 402M/682M [00:08<00:05, 49.9MB/s]
#
#
# speech_tokenizer/model.safetensors:  93% 632M/682M [00:09<00:00, 76.1MB/s]
#
#
# speech_tokenizer/model.safetensors: 100% 682M/682M [00:12<00:00, 56.7MB/s]
#
# model.safetensors:   7% 268M/3.86G [00:15<00:45, 78.6MB/s]
# model.safetensors:  14% 536M/3.86G [00:18<02:09, 25.6MB/s]
# model.safetensors:  35% 1.34G/3.86G [00:18<00:26, 96.7MB/s]
# model.safetensors:  49% 1.88G/3.86G [00:21<00:16, 120MB/s]
# model.safetensors:  90% 3.49G/3.86G [00:29<00:02, 164MB/s]
# model.safetensors: 100% 3.86G/3.86G [00:32<00:00, 119MB/s]
# Fetching 13 files: 100% 13/13 [00:32<00:00,  2.51s/it]
# Setting `pad_token_id` to `eos_token_id`:2150 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2150 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2150 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2150 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2150 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2150 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2150 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2150 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2150 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2150 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2150 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2150 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2150 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2150 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2150 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2150 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2150 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2150 for open-end generation.
